# %%
# !python -m pip install fastapi[all]
# Out:
# ...
#      ---------------------------------------- 0.0/50.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/50.5 kB ? eta -:--:--
#      ---------------------------------------- 50.5/50.5 kB 1.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/45.7 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/45.7 kB ? eta -:--:--
#      -------------------------------------- 45.7/45.7 kB 563.0 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/58.3 kB ? eta -:--:--
#      -------------------------- ----------- 41.0/58.3 kB 991.0 kB/s eta 0:00:01
#      --------------------------------- ---- 51.2/58.3 kB 871.5 kB/s eta 0:00:01
#      -------------------------------------- 58.3/58.3 kB 510.8 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/75.9 kB ? eta -:--:--
#    ---------------- ----------------------- 30.7/75.9 kB ? eta -:--:--
#    ---------------- ----------------------- 30.7/75.9 kB ? eta -:--:--
# ...
